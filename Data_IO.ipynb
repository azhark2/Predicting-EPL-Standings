# %% [markdown]
# # Data I/O
# ### Purpose: be able to import and work with the [European Soccer Database](https://www.kaggle.com/hugomathien/soccer)

# %%
#import packages
import sqlite3
import pandas as pd

# %%
#create a connection with the SQLite database
with sqlite3.connect('database.sqlite') as con:
    
    #these lines allow us to get the names of all of the tables in the database
    cursor = con.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    
    #the names of all of the tables are stored in the variable table_names
    table_names = cursor.fetchall()
    
    #we'll print the table names in the file
    print('Tables in file: ', table_names)
    
    #we're going to convert every table from the sqlite database into individual pandas dataframes
    #(except for the first entry in table_name: 'sqlite_sequence')
    
    #we'll store pandas dataframes in the list tables
    tables = []
    
    #loop through each table name in the table_names (except for the first one)
    for i in table_names[1:]:
        
        #create the string command to retrieve table from database (e.g., SELECT * from Player)
        command = "SELECT * from " + i[0]
        
        #retrieve the table, make it a pandas dataframe, and append it to our tables list
        tables.append(pd.read_sql_query(command, con))

        
#now we'll loop through each pandas dataframe and save it as its own .csv file, with the file name being its table name
for i in range(len(tables)):
    tables[i].to_csv(table_names[i+1][0]+'.csv', index_label='index')
# Out:
# Tables in file:  [('sqlite_sequence',), ('Player_Attributes',), ('Player',), ('Match',), ('League',), ('Country',), ('Team',), ('Team_Attributes',)]

# %%
with sqlite3.connect('database.sqlite') as con:
    
    #these lines allow us to get the names of all of the tables in the database
    cursor = con.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    
    #the names of all of the tables are stored in the variable table_names
    table_names = cursor.fetchall()
    
    #we'll print the table names in the file
    print('Tables in file: ', table_names)
    
    #we're going to convert every table from the sqlite database into individual pandas dataframes
    #(except for the first entry in table_name: 'sqlite_sequence')
    
    #we'll store pandas dataframes in the list tables
    tables = []
    
    #loop through each table name in the table_names (except for the first one)
    for i in table_names[1:]:
        
        #create the string command to retrieve table from database (e.g., SELECT * from Player)
        command = "SELECT * from " + i[0]
        
        #retrieve the table, make it a pandas dataframe, and append it to our tables list
        tables.append(pd.read_sql_query(command, con))

        
#now we'll loop through each pandas dataframe and save it as its own .csv file, with the file name being its table name
for i in range(len(tables)):
    tables[i].to_csv(table_names[i+1][0]+'.csv', index_label='index')

# %%
df = pd.read_csv('Country.csv')
df
# Out:
#     index     id         name
# 0       0      1      Belgium
# 1       1   1729      England
# 2       2   4769       France
# 3       3   7809      Germany
# 4       4  10257        Italy
# 5       5  13274  Netherlands
# 6       6  15722       Poland
# 7       7  17642     Portugal
# 8       8  19694     Scotland
# 9       9  21518        Spain
# 10     10  24558  Switzerland

# %%
df = pd.read_csv('League.csv')
df.head()
# Out:
#    index     id  country_id                    name
# 0      0      1           1  Belgium Jupiler League
# 1      1   1729        1729  England Premier League
# 2      2   4769        4769          France Ligue 1
# 3      3   7809        7809   Germany 1. Bundesliga
# 4      4  10257       10257           Italy Serie A

# %%
df = pd.read_csv('Match.csv')
df.head()
# Out:
#    index  id  country_id  league_id     season  stage                 date  \
# 0      0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1      1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2      2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3      3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4      4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  ...    SJA   VCH   VCD  \
# 0        492473              9987              9993  ...   4.00  1.65  3.40
# 1        492474             10000              9994  ...   3.80  2.00  3.25
# 2        492475              9984              8635  ...   2.50  2.35  3.25
# 3        492476              9991              9998  ...   7.50  1.45  3.75
# 4        492477              7947              9985  ...   1.73  4.50  3.40
#
#     VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
# [5 rows x 116 columns]

# %%
df = pd.read_csv('Player.csv')
df.head()
# Out:
#    index  id  player_api_id         player_name  player_fifa_api_id  \
# 0      0   1         505942  Aaron Appindangoye              218353
# 1      1   2         155782     Aaron Cresswell              189615
# 2      2   3         162549         Aaron Doran              186170
# 3      3   4          30572       Aaron Galindo              140161
# 4      4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
df = pd.read_csv('Player_Attributes.csv')
df.head()
# Out:
#    index  id  player_fifa_api_id  player_api_id                 date  \
# 0      0   1              218353         505942  2016-02-18 00:00:00
# 1      1   2              218353         505942  2015-11-19 00:00:00
# 2      2   3              218353         505942  2015-09-21 00:00:00
# 3      3   4              218353         505942  2015-03-20 00:00:00
# 4      4   5              218353         505942  2007-02-22 00:00:00
#
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate     ...       vision  penalties  marking  \
# 0              medium     ...         54.0       48.0     65.0
# 1              medium     ...         54.0       48.0     65.0
# 2              medium     ...         54.0       48.0     65.0
# 3              medium     ...         53.0       47.0     62.0
# 4              medium     ...         53.0       47.0     62.0
#
#    standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0             69.0            69.0        6.0         11.0        10.0
# 1             69.0            69.0        6.0         11.0        10.0
# 2             66.0            69.0        6.0         11.0        10.0
# 3             63.0            66.0        5.0         10.0         9.0
# 4             63.0            66.0        5.0         10.0         9.0
#
#    gk_positioning  gk_reflexes
# 0             8.0          8.0
# 1             8.0          8.0
# 2             8.0          8.0
# 3             7.0          7.0
# 4             7.0          7.0
#
# [5 rows x 43 columns]

# %%
df = pd.read_csv('Team.csv')
df
# Out:
#      index     id  team_api_id  team_fifa_api_id           team_long_name  \
# 0        0      1         9987             673.0                 KRC Genk
# 1        1      2         9993             675.0             Beerschot AC
# 2        2      3        10000           15005.0         SV Zulte-Waregem
# 3        3      4         9994            2007.0         Sporting Lokeren
# 4        4      5         9984            1750.0        KSV Cercle Brugge
# 5        5      6         8635             229.0           RSC Anderlecht
# 6        6      7         9991             674.0                 KAA Gent
# 7        7      8         9998            1747.0                RAEC Mons
# 8        8      9         7947               NaN            FCV Dender EH
# 9        9     10         9985             232.0        Standard de Liège
# 10      10     11         8203          110724.0              KV Mechelen
# 11      11     12         8342             231.0           Club Brugge KV
# 12      12     13         9999             546.0            KSV Roeselare
# 13      13     14         8571          100081.0              KV Kortrijk
# 14      14     15         4049               NaN                   Tubize
# 15      15     16         9996          111560.0     Royal Excel Mouscron
# 16      16     17        10001             681.0             KVC Westerlo
# 17      17     18         9986             670.0       Sporting Charleroi
# 18      18    614         9997             680.0        Sint-Truidense VV
# 19      19   1034         9989             239.0                Lierse SK
# 20      20   1042         6351            2013.0                KAS Eupen
# 21      21   1513         1773          100087.0      Oud-Heverlee Leuven
# 22      22   2004         8475          110913.0         Waasland-Beveren
# 23      23   2476         8573             682.0              KV Oostende
# 24      24   2510       274581          111560.0     Royal Excel Mouscron
# 25      25   3457        10260              11.0        Manchester United
# 26      26   3458        10261              13.0         Newcastle United
# 27      27   3459         9825               1.0                  Arsenal
# 28      28   3460         8659             109.0     West Bromwich Albion
# 29      29   3461         8472             106.0               Sunderland
# ..     ...    ...          ...               ...                      ...
# 269    269  43053         9906             240.0          Atlético Madrid
# 270    270  43054         9864             573.0                Málaga CF
# 271    271  43800         9868            1742.0     Xerez Club Deportivo
# 272    272  43803         8394             244.0            Real Zaragoza
# 273    273  43804         9867             260.0              CD Tenerife
# 274    274  44557        10278          100879.0  Hércules Club de Fútbol
# 275    275  44565         8581            1853.0               Levante UD
# 276    276  44569         8560             457.0            Real Sociedad
# 277    277  45330         7878          110832.0               Granada CF
# 278    278  45333         8370             480.0           Rayo Vallecano
# 279    279  46087         9910             450.0         RC Celta de Vigo
# 280    280  46848        10268             468.0                 Elche CF
# 281    281  47605         8372             467.0                 SD Eibar
# 282    282  47612         7869            1867.0               Córdoba CF
# 283    283  48358         8306             472.0            UD Las Palmas
# 284    284  49115         9956             322.0  Grasshopper Club Zürich
# 285    285  49116         6493            1714.0            AC Bellinzona
# 286    286  49117        10192             900.0           BSC Young Boys
# 287    287  49118         9931             896.0                 FC Basel
# 288    288  49119         9930             434.0                 FC Aarau
# 289    289  49120        10179          110770.0                  FC Sion
# 290    290  49121        10199             897.0                FC Luzern
# 291    291  49122         9824             286.0                 FC Vaduz
# 292    292  49123         7955             435.0          Neuchâtel Xamax
# 293    293  49124        10243             894.0                FC Zürich
# 294    294  49479        10190             898.0            FC St. Gallen
# 295    295  49837        10191            1715.0                  FC Thun
# 296    296  50201         9777             324.0              Servette FC
# 297    297  50204         7730            1862.0       FC Lausanne-Sports
# 298    298  51606         7896               NaN                   Lugano
#
#     team_short_name
# 0               GEN
# 1               BAC
# 2               ZUL
# 3               LOK
# 4               CEB
# 5               AND
# 6               GEN
# 7               MON
# 8               DEN
# 9               STL
# 10              MEC
# 11              CLB
# 12              ROS
# 13              KOR
# 14              TUB
# 15              MOU
# 16              WES
# 17              CHA
# 18              STT
# 19              LIE
# 20              EUP
# 21              O-H
# 22              WAA
# 23              OOS
# 24              MOP
# 25              MUN
# 26              NEW
# 27              ARS
# 28              WBA
# 29              SUN
# ..              ...
# 269             AMA
# 270             MAL
# 271             XER
# 272             ZAR
# 273             TEN
# 274             HER
# 275             LEV
# 276             SOC
# 277             GRA
# 278             RAY
# 279             CEL
# 280             ELC
# 281             EIB
# 282             COR
# 283             LAS
# 284             GRA
# 285             BEL
# 286              YB
# 287             BAS
# 288             AAR
# 289             SIO
# 290             LUZ
# 291             VAD
# 292             XAM
# 293             ZUR
# 294             GAL
# 295             THU
# 296             SER
# 297             LAU
# 298             LUG
#
# [299 rows x 6 columns]

# %%
df = pd.read_csv('Team_Attributes.csv')
df.head()
# Out:
#    index  id  team_fifa_api_id  team_api_id                 date  \
# 0      0   1               434         9930  2010-02-22 00:00:00
# 1      1   2               434         9930  2014-09-19 00:00:00
# 2      2   3               434         9930  2015-09-10 00:00:00
# 3      3   4                77         8485  2010-02-22 00:00:00
# 4      4   5                77         8485  2011-02-22 00:00:00
#
#    buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                60              Balanced                   NaN
# 1                52              Balanced                  48.0
# 2                47              Balanced                  41.0
# 3                70                  Fast                   NaN
# 4                47              Balanced                   NaN
#
#   buildUpPlayDribblingClass  buildUpPlayPassing            ...             \
# 0                    Little                  50            ...
# 1                    Normal                  56            ...
# 2                    Normal                  54            ...
# 3                    Little                  70            ...
# 4                    Little                  52            ...
#
#   chanceCreationShooting chanceCreationShootingClass  \
# 0                     55                      Normal
# 1                     64                      Normal
# 2                     64                      Normal
# 3                     70                        Lots
# 4                     52                      Normal
#
#    chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                       Organised              50                Medium
# 1                       Organised              47                Medium
# 2                       Organised              47                Medium
# 3                       Organised              60                Medium
# 4                       Organised              47                Medium
#
#   defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                55                   Press               45
# 1                44                   Press               54
# 2                44                   Press               54
# 3                70                  Double               70
# 4                47                   Press               52
#
#   defenceTeamWidthClass  defenceDefenderLineClass
# 0                Normal                     Cover
# 1                Normal                     Cover
# 2                Normal                     Cover
# 3                  Wide                     Cover
# 4                Normal                     Cover
#
# [5 rows x 26 columns]
